# %%
import pandas as pd
from pandas_datareader import data
import datetime as dt          
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv("SpotifyFeatures.csv")
df=pd.DataFrame(data)
data
# Out:
#         genre               artist_name  \
# 0       Movie            Henri Salvador
# 1       Movie         Martin & les fées
# 2       Movie           Joseph Williams
# 3       Movie            Henri Salvador
# 4       Movie              Fabien Nataf
# 5       Movie            Henri Salvador
# 6       Movie         Martin & les fées
# 7       Movie               Laura Mayne
# 8       Movie                    Chorus
# 9       Movie       Le Club des Juniors
# 10      Movie         Leopold Stokowski
# 11      Movie              Randy Newman
# 12      Movie      Idoles De La Musique
# 13      Movie                    Chorus
# 14      Movie        Richard M. Sherman
# 15      Movie               Michel Roux
# 16      Movie        Jean Claude Corbel
# 17      Movie             Bernard Minet
# 18      Movie            Henri Salvador
# 19      Movie                    Amalya
# 20      Movie         Martin & les fées
# 21      Movie                  Dorothée
# ...

# %%
df
# Out:
#         genre               artist_name  \
# 0       Movie            Henri Salvador
# 1       Movie         Martin & les fées
# 2       Movie           Joseph Williams
# 3       Movie            Henri Salvador
# 4       Movie              Fabien Nataf
# 5       Movie            Henri Salvador
# 6       Movie         Martin & les fées
# 7       Movie               Laura Mayne
# 8       Movie                    Chorus
# 9       Movie       Le Club des Juniors
# 10      Movie         Leopold Stokowski
# 11      Movie              Randy Newman
# 12      Movie      Idoles De La Musique
# 13      Movie                    Chorus
# 14      Movie        Richard M. Sherman
# 15      Movie               Michel Roux
# 16      Movie        Jean Claude Corbel
# 17      Movie             Bernard Minet
# 18      Movie            Henri Salvador
# 19      Movie                    Amalya
# 20      Movie         Martin & les fées
# 21      Movie                  Dorothée
# ...

# %%
df.dropValence()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-55-a13f072697c2> in <module>
# ----> 1 df.dropValence()
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'dropValence'

# %%
fig, ax = plt.subplots() 
ax.scatter(df["danceability"],df["energy"],alpha=0.3, marker = 'x',s =0.1,c=Color)
ax.set_title('Danceability vs. Energy', loc='right', fontsize=14, fontweight = "bold")
ax.set_xlabel("Danceability")
ax.set_ylabel("Energy")
ax.spines["right"].set_visible(False)
ax.spines["top"].set_visible(False)

# %%
dance = df[df['genre']=='Dance']
soul = df[df['genre']=='Soul']
electronic=df[df['genre']=='Electronic']
blues=df[df['genre']=='Blues']
rnb=df[df['genre']=='R&B']
folk=df[df['genre']=='Folk']
country=df[df['genre']=='Country']
opera = df[df['genre']=='Opera']
jazz=df[df['genre']=='Jazz']

# %%
fig, ax = plt.subplots() 
ax.scatter(dance["danceability"],dance["energy"],alpha=0.3, marker = 'x',s =5,)
ax.set_title('Danceability vs. Energy', loc='right', fontsize=14, fontweight = "bold")
ax.set_xlabel("Danceability")
ax.set_ylabel("Energy")
ax.spines["right"].set_visible(False)
ax.spines["top"].set_visible(False)

# %%
pop = df[df['genre']=='Pop']
pop
# Out:
#        genre                       artist_name  \
# 107802   Pop                     Ariana Grande
# 107803   Pop                       Post Malone
# 107804   Pop                     Ariana Grande
# 107805   Pop                           J. Cole
# 107806   Pop                       Post Malone
# 107807   Pop                      Travis Scott
# 107808   Pop                            Halsey
# 107809   Pop                            Khalid
# 107810   Pop                         Sam Smith
# 107811   Pop                     Ariana Grande
# 107812   Pop                        Marshmello
# 107813   Pop                     Ariana Grande
# 107814   Pop                     Ariana Grande
# 107815   Pop                            Khalid
# 107816   Pop                    Jonas Brothers
# 107817   Pop                     Ariana Grande
# 107818   Pop                     Ariana Grande
# 107819   Pop                              Lauv
# 107820   Pop                     Ariana Grande
# ...

# %%
fig, ax = plt.subplots() 
ax.scatter(pop["danceability"],pop["energy"],alpha=0.3, marker = 'x',s =5)
ax.set_title('Danceability vs. Energy', loc='right', fontsize=14, fontweight = "bold")
ax.set_xlabel("Danceability")
ax.set_ylabel("Energy")
ax.spines["right"].set_visible(False)
ax.spines["top"].set_visible(False)

# %%
df.dtypes
# Out:
# genre                object
# artist_name          object
# track_name           object
# track_id             object
# popularity            int64
# acousticness        float64
# danceability        float64
# duration_ms           int64
# energy              float64
# instrumentalness    float64
# key                  object
# liveness            float64
# loudness            float64
# mode                 object
# speechiness         float64
# tempo               float64
# time_signature       object
# valence             float64
# dtype: object

# %%
df.loc[(df.valence <=0.5) &(df.danceability<=0.5) ,'control'] = 'low low'
df.loc[(0.5<df.valence) & (df.danceability<=0.5),'control'] = 'high low'
df.loc[(df.valence<=0.5)&(0.5<df.danceability),'control']='low high'
df.loc[(0.5<df.valence)&(0.5<df.danceability),'control']='high high'
df.loc[df.energy <=0.25 ,'Energy'] = 'low'
df.loc[(0.25<df.energy) & (df.energy<=0.5),'Energy'] = 'slightly low'
df.loc[(df.energy<=0.75)&(0.5<df.energy),'Energy']='slightly high'
df.loc[0.75<df.energy,'Energy']='high'
df.loc[df.acousticness <=0.25 ,'Acousticness'] = 'electric'
df.loc[(0.25<df.acousticness) & (df.acousticness<=0.5),'Acousticness'] = 'slightly electric'
df.loc[(df.acousticness<=0.75)&(0.5<df.acousticness),'Acousticness']='slightly acoustic'
df.loc[0.75<df.acousticness,'Acousticness']='acoustic'

# %%
alternative =df[df['genre']=="Alternative"]
popList=pop["Energy"].tolist()
soulList=soul["Energy"].tolist()
alternativeList = alternative["Energy"].tolist()
electronicList=electronic["Energy"].tolist()
rnbList=rnb["Energy"].tolist()
colourList=df["Energy"].tolist()
bluesList=blues["Energy"].tolist()
jazzList=jazz["Energy"].tolist()

jazzColour=[dic.get(colors, colors) for colors in jazzList]
operaColour=[dic.get(colors, colors) for colors in operaList]
countryColour=[dic.get(colors, colors) for colors in countryList]
Color=[dic.get(colors, colors) for colors in colourList]
rnbColour=[dic.get(colors, colors) for colors in rnbList]
folkColour=[dic.get(colors, colors) for colors in folkList]
bluesColour=[dic.get(colors, colors) for colors in bluesList]
soulColour=[dic.get(colors, colors) for colors in soulList]
alternativeColour=[dic.get(colors, colors) for colors in alternativeList]
electronicColour=[dic.get(colors, colors) for colors in electronicList]
dance1Colour = [dic.get(colors, colors) for colors in dance1List]
dance2Colour = [dic.get(colors, colors) for colors in dance2List]
dance3Colour = [dic.get(colors, colors) for colors in dance3List]
dance4Colour = [dic.get(colors, colors) for colors in dance4List]
popColour=[dic.get(colors, colors) for colors in popList]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Energy'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-95-65254df6da96> in <module>
# ...

# %%
jazz1=jazz[(jazz['tempo']<125) &  (jazz['danceability']>=0) &(jazz['danceability']<0.2)]
jazz2=jazz[(jazz['tempo']<125) &  (jazz['danceability']>=0.2) &(jazz['danceability']<0.4)]
jazz3=jazz[(jazz['tempo']<125) &  (jazz['danceability']>=0.6) &(jazz['danceability']<0.8)]
jazz4=jazz[(jazz['tempo']<125) &  (jazz['danceability']>=0.8) &(jazz['danceability']<1)]

# %%
jazz1List=jazz1["mode"].tolist()
jazz2List=jazz2["mode"].tolist()
jazz3List=jazz3["mode"].tolist()
jazz4List=jazz4["mode"].tolist()
dic = {"Major":"red","Minor":"blue"}
jazz1Colour=[dic.get(colors, colors) for colors in jazz1List]
jazz2Colour=[dic.get(colors, colors) for colors in jazz2List]
jazz3Colour=[dic.get(colors, colors) for colors in jazz3List]
jazz4Colour=[dic.get(colors, colors) for colors in jazz4List]

# %%
df['valence/energy']=df['valence']/df['energy']
df['energy/danceability']=df['energy']/df['danceability']
df['valence/danceability']=df['valence']/df['danceability']
df
# Out:
#         genre               artist_name  \
# 0       Movie            Henri Salvador
# 1       Movie         Martin & les fées
# 2       Movie           Joseph Williams
# 3       Movie            Henri Salvador
# 4       Movie              Fabien Nataf
# 5       Movie            Henri Salvador
# 6       Movie         Martin & les fées
# 7       Movie               Laura Mayne
# 8       Movie                    Chorus
# 9       Movie       Le Club des Juniors
# 10      Movie         Leopold Stokowski
# 11      Movie              Randy Newman
# 12      Movie      Idoles De La Musique
# 13      Movie                    Chorus
# 14      Movie        Richard M. Sherman
# 15      Movie               Michel Roux
# 16      Movie        Jean Claude Corbel
# 17      Movie             Bernard Minet
# 18      Movie            Henri Salvador
# 19      Movie                    Amalya
# 20      Movie         Martin & les fées
# 21      Movie                  Dorothée
# ...

# %%
df['energy-danceability'] = abs(df['energy']-df['danceability'])
df['valence-danceability'] = abs(df['valence']-df['danceability'])

# %%
df.describe()
# Out:
#           popularity   acousticness   danceability   duration_ms  \
# count  232725.000000  232725.000000  232725.000000  2.327250e+05
# mean       41.127502       0.368560       0.554364  2.351223e+05
# std        18.189948       0.354768       0.185608  1.189359e+05
# min         0.000000       0.000000       0.056900  1.538700e+04
# 25%        29.000000       0.037600       0.435000  1.828570e+05
# 50%        43.000000       0.232000       0.571000  2.204270e+05
# 75%        55.000000       0.722000       0.692000  2.657680e+05
# max       100.000000       0.996000       0.989000  5.552917e+06
#
#               energy  instrumentalness       liveness       loudness  \
# count  232725.000000     232725.000000  232725.000000  232725.000000
# mean        0.570958          0.148301       0.215009      -9.569885
# std         0.263456          0.302768       0.198273       5.998204
# min         0.000020          0.000000       0.009670     -52.457000
# ...

# %% [markdown]
# Since there were so many factors to consider, I decided to take two similar factors and control them. I compared the values of dancability, energy and valence to each other and reached a conclusion the energy&danceability and valence&danceability were relatively similar. To decided which one was more silimiar to each other, I compared the subbtractions between each values. As it can be seen in the graph above, the mean, percentile , std and max were all lower for (valence - danceability) than (energy - danceability).

# %%
df.dropna()
# Out:
#         genre               artist_name  \
# 0       Movie            Henri Salvador
# 1       Movie         Martin & les fées
# 2       Movie           Joseph Williams
# 3       Movie            Henri Salvador
# 4       Movie              Fabien Nataf
# 5       Movie            Henri Salvador
# 6       Movie         Martin & les fées
# 7       Movie               Laura Mayne
# 8       Movie                    Chorus
# 9       Movie       Le Club des Juniors
# 10      Movie         Leopold Stokowski
# 11      Movie              Randy Newman
# 12      Movie      Idoles De La Musique
# 13      Movie                    Chorus
# 14      Movie        Richard M. Sherman
# 15      Movie               Michel Roux
# 16      Movie        Jean Claude Corbel
# 17      Movie             Bernard Minet
# 18      Movie            Henri Salvador
# 19      Movie                    Amalya
# 20      Movie         Martin & les fées
# 21      Movie                  Dorothée
# ...

# %%
df.sort_values(by=['danceability'])
# Out:
#                    genre               artist_name  \
# 217809             World          Stars Of The Lid
# 221323             World                   Eluvium
# 200052        Soundtrack             Ramin Djawadi
# 205858        Soundtrack       James Newton Howard
# 220779             World          Stars Of The Lid
# 199303        Soundtrack       Marcin Przybyłowicz
# 202574        Soundtrack               Max Richter
# 126691         Classical              Howard Shore
# 200989        Soundtrack              Howard Shore
# 219896             World          Stars Of The Lid
# 204978        Soundtrack              James Horner
# 58313              Opera            Richard Wagner
# 82048              Opera            Richard Wagner
# 203689        Soundtrack             Bear McCreary
# 199792        Soundtrack             Randy Edelman
# 197988        Soundtrack              Jeremy Soule
# 79795              Opera             Georges Bizet
# ...

# %%
fig, ax = plt.subplots()
ax.scatter(dance["acousticness"],dance["popularity"],alpha=1, marker = 'o',s =12,c=danceColour)
ax.set_title('Dance Music', loc='right', fontsize=14, fontweight = "bold")
ax.set_xlabel("Acousticness")
ax.set_ylabel("Popularity")
ax.spines["right"].set_visible(False)
ax.spines["top"].set_visible(False)
plt.gcf().set_size_inches((20,20))
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
dance1=dance[dance['control']=='low low']
dance2=dance[dance['control']=='low high']
dance3=dance[dance['control']=='high low']
dance4=dance[dance['control']=='high high']
pop1=pop[pop['control']=='low low']
pop2=pop[pop['control']=='low high']
pop3=pop[pop['control']=='high low']
pop4=pop[pop['control']=='high high']
electronic1=electronic[electronic['control']=='low low']
electronic2=electronic[electronic['control']=='low high']
electronic3=electronic[electronic['control']=='high low']
electronic4=electronic[electronic['control']=='high high']
rnb1=rnb[rnb['control']=='low low']
rnb2=rnb[rnb['control']=='low high']
rnb3=rnb[rnb['control']=='high low']
rnb4=rnb[rnb['control']=='high high']

# %%
dance1List=dance1["Energy"].tolist()
dance2List=dance2["Energy"].tolist()
dance3List=dance3["Energy"].tolist()
dance4List=dance4["Energy"].tolist()
dance1Acous=dance1["Acousticness"].tolist()
dance2Acous=dance2["Acousticness"].tolist()
dance3Acous=dance3["Acousticness"].tolist()
dance4Acous=dance4["Acousticness"].tolist()
pop1List=pop1["Energy"].tolist()
pop2List=pop2["Energy"].tolist()
pop3List=pop3["Energy"].tolist()
pop4List=pop4["Energy"].tolist()
pop1Acous=pop1["Acousticness"].tolist()
pop2Acous=pop2["Acousticness"].tolist()
pop3Acous=pop3["Acousticness"].tolist()
pop4Acous=pop4["Acousticness"].tolist()
electronic1List=electronic1["Energy"].tolist()
electronic2List=electronic2["Energy"].tolist()
electronic3List=electronic3["Energy"].tolist()
electronic4List=electronic4["Energy"].tolist()
electronic1Acous=electronic1["Acousticness"].tolist()
electronic2Acous=electronic2["Acousticness"].tolist()
electronic3Acous=electronic3["Acousticness"].tolist()
electronic4Acous=electronic4["Acousticness"].tolist()
rnb1List=rnb1["Energy"].tolist()
rnb2List=rnb2["Energy"].tolist()
rnb3List=rnb3["Energy"].tolist()
rnb4List=rnb4["Energy"].tolist()
rnb1Acous=rnb1["Acousticness"].tolist()
rnb2Acous=rnb2["Acousticness"].tolist()
rnb3Acous=rnb3["Acousticness"].tolist()
rnb4Acous=rnb4["Acousticness"].tolist()
dic = {"low":"blue","slightly low":"green","slightly high":"yellow","high":"red"}
dicA = {"electric":"yellow","slightly electric":"red","slightly acoustic":"green","acoustic":"blue"}
dance1ColourA = [dicA.get(colors, colors) for colors in dance1Acous]
dance2ColourA = [dicA.get(colors, colors) for colors in dance2Acous]
dance3ColourA = [dicA.get(colors, colors) for colors in dance3Acous]
dance4ColourA = [dicA.get(colors, colors) for colors in dance4Acous]
dance1Colour = [dic.get(colors, colors) for colors in dance1List]
dance2Colour = [dic.get(colors, colors) for colors in dance2List]
dance3Colour = [dic.get(colors, colors) for colors in dance3List]
dance4Colour = [dic.get(colors, colors) for colors in dance4List]
pop1ColourA = [dicA.get(colors, colors) for colors in pop1Acous]
pop2ColourA = [dicA.get(colors, colors) for colors in pop2Acous]
pop3ColourA = [dicA.get(colors, colors) for colors in pop3Acous]
pop4ColourA = [dicA.get(colors, colors) for colors in pop4Acous]
pop1Colour = [dic.get(colors, colors) for colors in pop1List]
pop2Colour = [dic.get(colors, colors) for colors in pop2List]
pop3Colour = [dic.get(colors, colors) for colors in pop3List]
pop4Colour = [dic.get(colors, colors) for colors in pop4List]
electronic1ColourA = [dicA.get(colors, colors) for colors in electronic1Acous]
electronic2ColourA = [dicA.get(colors, colors) for colors in electronic2Acous]
electronic3ColourA = [dicA.get(colors, colors) for colors in electronic3Acous]
electronic4ColourA = [dicA.get(colors, colors) for colors in electronic4Acous]
electronic1Colour = [dic.get(colors, colors) for colors in electronic1List]
electronic2Colour = [dic.get(colors, colors) for colors in electronic2List]
electronic3Colour = [dic.get(colors, colors) for colors in electronic3List]
electronic4Colour = [dic.get(colors, colors) for colors in electronic4List]
rnb1ColourA = [dicA.get(colors, colors) for colors in rnb1Acous]
rnb2ColourA = [dicA.get(colors, colors) for colors in rnb2Acous]
rnb3ColourA = [dicA.get(colors, colors) for colors in rnb3Acous]
rnb4ColourA = [dicA.get(colors, colors) for colors in rnb4Acous]
rnb1Colour = [dic.get(colors, colors) for colors in rnb1List]
rnb2Colour = [dic.get(colors, colors) for colors in rnb2List]
rnb3Colour = [dic.get(colors, colors) for colors in rnb3List]
rnb4Colour = [dic.get(colors, colors) for colors in rnb4List]

# %%
fig, ax = plt.subplots(nrows = 2, ncols = 2, sharey = True, sharex = True, figsize = (20,16)) 

corr_mat1 = dance1.corr()
corr_mat2 = dance2.corr()
corr_mat3 = dance3.corr()
corr_mat4 = dance4.corr()
corr = [corr_mat1, corr_mat2, corr_mat3, corr_mat4]

ax[0][0].scatter(dance1["acousticness"],dance1["popularity"], s =10,c=dance1Colour, alpha=0.3)
ax[0][1].scatter(dance2["acousticness"],dance2["popularity"], s =10, c=dance2Colour,alpha=0.2)
ax[1][0].scatter(dance3["acousticness"],dance3["popularity"], s =10, c=dance3Colour,alpha=0.4)
ax[1][1].scatter(dance4["acousticness"],dance4["popularity"], s =10, c=dance4Colour,alpha=0.2)
fig.suptitle("Popularity of Dance music", fontsize = 20, fontweight = "bold")
title = ["valence<=0.5 & danceability<=0.5","valence<=0.5 & 0.5<danceability","0.5<valence & danceability<=0.5","0.5<valence & 0.5<danceability"]
count=0
for var in ax:
    for i in var:
        i.spines["right"].set_visible(False) 
        i.spines["top"].set_visible(False)
        i.set_title(title[count])
        cr = corr[count].acousticness["popularity"]
        message = "Correlation = " + str(round(cr,4))
        i.text( 1,0,message, horizontalalignment='right')
        count=count+1
ax[0][0].set_ylabel("Popularity")
ax[1][0].set_ylabel("Popularity")
ax[1][1].set_xlabel("Acousticness")
ax[1][0].set_xlabel("Acousticness")
plt.show()
print("Energy is shown by colours: ")
print("       energy<=0.25 - blue")
print("0.25<energy<=0.5 - green")
print("0.5<energy<=0.75 - yellow")
print("    0.75<energy<=1 - red")
# Out:
# Energy is shown by colours:
#        energy<=0.25 - blue
# 0.25<energy<=0.5 - green
# 0.5<energy<=0.75 - yellow
#     0.75<energy<=1 - red

# %%
fig, ax = plt.subplots(nrows = 2, ncols = 2, sharey = True, sharex = True, figsize = (20,16)) 

corr_mat1 = dance1.corr()
corr_mat2 = dance2.corr()
corr_mat3 = dance3.corr()
corr_mat4 = dance4.corr()
corr = [corr_mat1, corr_mat2, corr_mat3, corr_mat4]

ax[0][0].scatter(dance1["energy"],dance1["popularity"], s =10,c=dance1ColourA, alpha=0.3)
ax[0][1].scatter(dance2["energy"],dance2["popularity"], s =10, c=dance2ColourA,alpha=0.2)
ax[1][0].scatter(dance3["energy"],dance3["popularity"], s =10, c=dance3ColourA,alpha=0.4)
ax[1][1].scatter(dance4["energy"],dance4["popularity"], s =10, c=dance4ColourA,alpha=0.2)
fig.suptitle("Popularity of Dance music", fontsize = 20, fontweight = "bold")
title = ["valence<=0.5 & danceability<=0.5","valence<=0.5 & 0.5<danceability","0.5<valence & danceability<=0.5","0.5<valence & 0.5<danceability"]
count=0
for var in ax:
    for i in var:
        i.spines["right"].set_visible(False) 
        i.spines["top"].set_visible(False)
        i.set_title(title[count])
        cr = corr[count].energy["popularity"]
        message = "Correlation = " + str(round(cr,4))
        i.text( 1,0,message, horizontalalignment='right')
        count=count+1
ax[0][0].set_ylabel("Popularity")
ax[1][0].set_ylabel("Popularity")
ax[1][1].set_xlabel("Energy")
ax[1][0].set_xlabel("Energy")
plt.show()
print("Acousticness is shown by colours: ")
print("       acousticness<=0.25 - yellow")
print("0.25<acousticness<=0.5 - red")
print("0.5<acousticness<=0.75 - green")
print("    0.75<acousticness<=1 - blue")
# Out:
# Acousticness is shown by colours:
#        acousticness<=0.25 - yellow
# 0.25<acousticness<=0.5 - red
# 0.5<acousticness<=0.75 - green
#     0.75<acousticness<=1 - blue

# %%
fig, ax = plt.subplots(nrows = 2, ncols = 2, sharey = True, sharex = True, figsize = (20,16)) 

corr_mat1 = pop1.corr()
corr_mat2 = pop2.corr()
corr_mat3 = pop3.corr()
corr_mat4 = pop4.corr()
corr = [corr_mat1, corr_mat2, corr_mat3, corr_mat4]

ax[0][0].scatter(pop1["acousticness"],pop1["popularity"], s =10,c=pop1Colour, alpha=0.3)
ax[0][1].scatter(pop2["acousticness"],pop2["popularity"], s =10, c=pop2Colour,alpha=0.2)
ax[1][0].scatter(pop3["acousticness"],pop3["popularity"], s =10, c=pop3Colour,alpha=0.4)
ax[1][1].scatter(pop4["acousticness"],pop4["popularity"], s =10, c=pop4Colour,alpha=0.2)
fig.suptitle("Popularity of Pop music", fontsize = 20, fontweight = "bold")
title = ["valence<=0.5 & danceability<=0.5","valence<=0.5 & 0.5<danceability","0.5<valence & danceability<=0.5","0.5<valence & 0.5<danceability"]
count=0
for var in ax:
    for i in var:
        i.spines["right"].set_visible(False) 
        i.spines["top"].set_visible(False)
        i.set_title(title[count])
        cr = corr[count].acousticness["popularity"]
        message = "Correlation = " + str(round(cr,4))
        i.text( 1,0,message, horizontalalignment='right')
        count=count+1
ax[0][0].set_ylabel("Popularity")
ax[1][0].set_ylabel("Popularity")
ax[1][1].set_xlabel("Acousticness")
ax[1][0].set_xlabel("Acousticness")
plt.show()
print("Energy is shown by colours: ")
print("       energy<=0.25 - blue")
print("0.25<energy<=0.5 - green")
print("0.5<energy<=0.75 - yellow")
print("    0.75<energy<=1 - red")
# Out:
# Energy is shown by colours:
#        energy<=0.25 - blue
# 0.25<energy<=0.5 - green
# 0.5<energy<=0.75 - yellow
#     0.75<energy<=1 - red

# %%
fig, ax = plt.subplots(nrows = 2, ncols = 2, sharey = True, sharex = True, figsize = (20,16)) 

corr_mat1 = pop1.corr()
corr_mat2 = pop2.corr()
corr_mat3 = pop3.corr()
corr_mat4 = pop4.corr()
corr = [corr_mat1, corr_mat2, corr_mat3, corr_mat4]

ax[0][0].scatter(pop1["energy"],pop1["popularity"], s =10,c=pop1ColourA, alpha=0.3)
ax[0][1].scatter(pop2["energy"],pop2["popularity"], s =10, c=pop2ColourA,alpha=0.2)
ax[1][0].scatter(pop3["energy"],pop3["popularity"], s =10, c=pop3ColourA,alpha=0.4)
ax[1][1].scatter(pop4["energy"],pop4["popularity"], s =10, c=pop4ColourA,alpha=0.2)
fig.suptitle("Popularity of Pop music", fontsize = 20, fontweight = "bold")
title = ["valence<=0.5 & danceability<=0.5","valence<=0.5 & 0.5<danceability","0.5<valence & danceability<=0.5","0.5<valence & 0.5<danceability"]
count=0
for var in ax:
    for i in var:
        i.spines["right"].set_visible(False) 
        i.spines["top"].set_visible(False)
        i.set_title(title[count])
        cr = corr[count].energy["popularity"]
        message = "Correlation = " + str(round(cr,4))
        i.text( 1,0,message, horizontalalignment='right')
        count=count+1
ax[0][0].set_ylabel("Popularity")
ax[1][0].set_ylabel("Popularity")
ax[1][1].set_xlabel("Energy")
ax[1][0].set_xlabel("Energy")
plt.show()
print("Acousticness is shown by colours: ")
print("       acousticness<=0.25 - yellow")
print("0.25<acousticness<=0.5 - red")
print("0.5<acousticness<=0.75 - green")
print("    0.75<acousticness<=1 - blue")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d4eb14794f2f> in <module>
# ----> 1 fig, ax = plt.subplots(nrows = 2, ncols = 2, sharey = True, sharex = True, figsize = (20,16))
#       2
#       3 corr_mat1 = pop1.corr()
#       4 corr_mat2 = pop2.corr()
#       5 corr_mat3 = pop3.corr()
#
# NameError: name 'plt' is not defined

# %%
fig, ax = plt.subplots(nrows = 2, ncols = 2, sharey = True, sharex = True, figsize = (20,16)) 

corr_mat1 = rnb1.corr()
corr_mat2 = rnb2.corr()
corr_mat3 = rnb3.corr()
corr_mat4 = rnb4.corr()
corr = [corr_mat1, corr_mat2, corr_mat3, corr_mat4]

ax[0][0].scatter(rnb1["acousticness"],rnb1["popularity"], s =10,c=rnb1Colour, alpha=0.3)
ax[0][1].scatter(rnb2["acousticness"],rnb2["popularity"], s =10, c=rnb2Colour,alpha=0.2)
ax[1][0].scatter(rnb3["acousticness"],rnb3["popularity"], s =10, c=rnb3Colour,alpha=0.4)
ax[1][1].scatter(rnb4["acousticness"],rnb4["popularity"], s =10, c=rnb4Colour,alpha=0.2)
fig.suptitle("Popularity of R&B music", fontsize = 20, fontweight = "bold")
title = ["valence<=0.5 & danceability<=0.5","valence<=0.5 & 0.5<danceability","0.5<valence & danceability<=0.5","0.5<valence & 0.5<danceability"]
count=0
for var in ax:
    for i in var:
        i.spines["right"].set_visible(False) 
        i.spines["top"].set_visible(False)
        i.set_title(title[count])
        cr = corr[count].acousticness["popularity"]
        message = "Correlation = " + str(round(cr,4))
        i.text( 1,0,message, horizontalalignment='right')
        count=count+1
ax[0][0].set_ylabel("Popularity")
ax[1][0].set_ylabel("Popularity")
ax[1][1].set_xlabel("Acousticness")
ax[1][0].set_xlabel("Acousticness")
plt.show()
print("Energy is shown by colours: ")
print("       energy<=0.25 - blue")
print("0.25<energy<=0.5 - green")
print("0.5<energy<=0.75 - yellow")
print("    0.75<energy<=1 - red")
# Out:
# Energy is shown by colours:
#        energy<=0.25 - blue
# 0.25<energy<=0.5 - green
# 0.5<energy<=0.75 - yellow
#     0.75<energy<=1 - red

# %%
fig, ax = plt.subplots(nrows = 2, ncols = 2, sharey = True, sharex = True, figsize = (20,16)) 

corr_mat1 = rnb1.corr()
corr_mat2 = rnb2.corr()
corr_mat3 = rnb3.corr()
corr_mat4 = rnb4.corr()
corr = [corr_mat1, corr_mat2, corr_mat3, corr_mat4]

ax[0][0].scatter(rnb1["energy"],rnb1["popularity"], s =10,c=rnb1ColourA, alpha=0.3)
ax[0][1].scatter(rnb2["energy"],rnb2["popularity"], s =10, c=rnb2ColourA,alpha=0.2)
ax[1][0].scatter(rnb3["energy"],rnb3["popularity"], s =10, c=rnb3ColourA,alpha=0.4)
ax[1][1].scatter(rnb4["energy"],rnb4["popularity"], s =10, c=rnb4ColourA,alpha=0.2)
fig.suptitle("Popularity of R&B music", fontsize = 20, fontweight = "bold")
title = ["valence<=0.5 & danceability<=0.5","valence<=0.5 & 0.5<danceability","0.5<valence & danceability<=0.5","0.5<valence & 0.5<danceability"]
count=0
for var in ax:
    for i in var:
        i.spines["right"].set_visible(False) 
        i.spines["top"].set_visible(False)
        i.set_title(title[count])
        cr = corr[count].energy["popularity"]
        message = "Correlation = " + str(round(cr,4))
        i.text( 1,0,message, horizontalalignment='right')
        count=count+1
ax[0][0].set_ylabel("Popularity")
ax[1][0].set_ylabel("Popularity")
ax[1][1].set_xlabel("Energy")
ax[1][0].set_xlabel("Energy")
plt.show()
print("Acousticness is shown by colours: ")
print("       acousticness<=0.25 - yellow")
print("0.25<acousticness<=0.5 - red")
print("0.5<acousticness<=0.75 - green")
print("    0.75<acousticness<=1 - blue")
# Out:
# Acousticness is shown by colours:
#        acousticness<=0.25 - yellow
# 0.25<acousticness<=0.5 - red
# 0.5<acousticness<=0.75 - green
#     0.75<acousticness<=1 - blue

# %%
fig, ax = plt.subplots(nrows = 2, ncols = 2, sharey = True, sharex = True, figsize = (20,16)) 

corr_mat1 = electronic1.corr()
corr_mat2 = electronic2.corr()
corr_mat3 = electronic3.corr()
corr_mat4 = electronic4.corr()
corr = [corr_mat1, corr_mat2, corr_mat3, corr_mat4]

ax[0][0].scatter(electronic1["acousticness"],electronic1["popularity"], s =10,c=electronic1Colour, alpha=0.3)
ax[0][1].scatter(electronic2["acousticness"],electronic2["popularity"], s =10, c=electronic2Colour,alpha=0.2)
ax[1][0].scatter(electronic3["acousticness"],electronic3["popularity"], s =10, c=electronic3Colour,alpha=0.4)
ax[1][1].scatter(electronic4["acousticness"],electronic4["popularity"], s =10, c=electronic4Colour,alpha=0.2)
fig.suptitle("Popularity of Electronic music", fontsize = 20, fontweight = "bold")
title = ["valence<=0.5 & danceability<=0.5","valence<=0.5 & 0.5<danceability","0.5<valence & danceability<=0.5","0.5<valence & 0.5<danceability"]
count=0
for var in ax:
    for i in var:
        i.spines["right"].set_visible(False) 
        i.spines["top"].set_visible(False)
        i.set_title(title[count])
        cr = corr[count].acousticness["popularity"]
        message = "Correlation = " + str(round(cr,4))
        i.text( 1,0,message, horizontalalignment='right')
        count=count+1
ax[0][0].set_ylabel("Popularity")
ax[1][0].set_ylabel("Popularity")
ax[1][1].set_xlabel("Acousticness")
ax[1][0].set_xlabel("Acousticness")
plt.show()
print("Energy is shown by colours: ")
print("       energy<=0.25 - blue")
print("0.25<energy<=0.5 - green")
print("0.5<energy<=0.75 - yellow")
print("    0.75<energy<=1 - red")
# Out:
# Energy is shown by colours:
#        energy<=0.25 - blue
# 0.25<energy<=0.5 - green
# 0.5<energy<=0.75 - yellow
#     0.75<energy<=1 - red
